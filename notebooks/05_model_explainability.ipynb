# %% [markdown]
# # 05 - Model Explainability with TreeSHAP and Feature Attributions
#
# Inspects global feature importances and local per-grid decision explanations.

# %%
import json

with open('../models/drainsense_xgb_v1_metadata.json') as f:
    meta = json.load(f)
print('Feature importances:')
for f in meta['feature_importances'][:8]:
    print(f"{f['feature']}: {f['importance']*100:.1f}%")
