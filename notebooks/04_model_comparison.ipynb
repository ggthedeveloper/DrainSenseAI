# %% [markdown]
# # 04 - Model Benchmarking: Dummy vs Logistic vs RF vs XGBoost
#
# Compares ROC-AUC, PR-AUC, F1-scores, and probability calibration across candidate models.

# %%
import json

with open('../models/drainsense_xgb_v1_metadata.json') as f:
    meta = json.load(f)
print('Model comparison metrics:')
print(json.dumps(meta['metrics_comparison'], indent=2))
