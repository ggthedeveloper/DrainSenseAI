# %% [markdown]
# # 01 - Exploratory Data Analysis of Vijayawada Rainfall & Inundation
#
# Explores CWC telemetry and Open-Meteo hourly rainfall during the September 2024 Budameru flood.

# %%
import pandas as pd
import numpy as np

df_rain = pd.read_csv('../data/raw/vijayawada_hourly_rainfall_telemetry.csv')
print(f'Total observations: {len(df_rain)}')
df_rain.head()
