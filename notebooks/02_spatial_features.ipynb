# %% [markdown]
# # 02 - Spatial Grid Generation & SRTM Topography
#
# Analyzes the 500m x 500m grid cells, elevation distributions, slope, and proximity to Krishna & Budameru.

# %%
import pandas as pd

df_spatial = pd.read_csv('../data/processed/vijayawada_grid_features.csv')
print(f'Total Grid Cells: {len(df_spatial)}')
df_spatial.describe()
