# %% [markdown]
# # 03 - Target Labeling & Class Balance Audit
#
# Demonstrates leakage-free spatio-temporal matching between storm hours and historical inundation footprints.

# %%
import pandas as pd

df_train = pd.read_csv('../data/processed/drainsense_train_dataset.csv')
pos_count = (df_train['flood_label'] == 1).sum()
print(f'Positive labels: {pos_count} ({pos_count/len(df_train)*100:.2f}%)')
df_train.groupby('flood_label')['rain_24h_mm'].mean()
